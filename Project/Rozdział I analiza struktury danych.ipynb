# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#DATA SOURCE

# %%
File_source = '../Data/nypd-motor-vehicle-collisions.csv'

# %%
df = pd.read_csv(File_source)
# Out:
# /tmp/ipykernel_29010/1857041183.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(File_source)

# %%
# WIELKOŚĆ ZBIORU DANYCH
headers = df.columns.tolist()
print("Lista nagłówków:")
for header in headers:
    print(header)

num_rows = len(df)
print("Liczba wierszy po COLLISION_ID:", num_rows)
# Out:
# Lista nagłówków:
# ACCIDENT DATE
# ACCIDENT TIME
# BOROUGH
# ZIP CODE
# LATITUDE
# LONGITUDE
# LOCATION
# ON STREET NAME
# CROSS STREET NAME
# OFF STREET NAME
# NUMBER OF PERSONS INJURED
# NUMBER OF PERSONS KILLED
# NUMBER OF PEDESTRIANS INJURED
# NUMBER OF PEDESTRIANS KILLED
# NUMBER OF CYCLIST INJURED
# NUMBER OF CYCLIST KILLED
# NUMBER OF MOTORIST INJURED
# NUMBER OF MOTORIST KILLED
# CONTRIBUTING FACTOR VEHICLE 1
# CONTRIBUTING FACTOR VEHICLE 2
# CONTRIBUTING FACTOR VEHICLE 3
# CONTRIBUTING FACTOR VEHICLE 4
# CONTRIBUTING FACTOR VEHICLE 5
# COLLISION_ID
# VEHICLE TYPE CODE 1
# VEHICLE TYPE CODE 2
# VEHICLE TYPE CODE 3
# VEHICLE TYPE CODE 4
# VEHICLE TYPE CODE 5
# Liczba wierszy po COLLISION_ID: 1612178

# %%
# SPRAWDZENIE POWTÓRZEŃ
unique_values = df['COLLISION_ID'].nunique()
print("Liczba unikalnych wartości w kolumnie 'COLLISION_ID':", unique_values)
# Out:
# Liczba unikalnych wartości w kolumnie 'COLLISION_ID': 1217957

# %%
# Wyświetlenie unikalnych wartości kolumn:
# ROBOCZE GRUPY DANYCH:
ranni = ['NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF CYCLIST INJURED',  'NUMBER OF MOTORIST INJURED']
zabici = ['NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST KILLED']
czynniki = ['CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5']
dzielnica = ['BOROUGH']

columns = ranni + zabici + czynniki + dzielnica
for column in columns:
    unique_values = df[column].unique()
    print(f"Unikalne wartości dla kolumny {column}:")
    for value in unique_values:
        print(value)
    print()
# Out:
# Unikalne wartości dla kolumny NUMBER OF PERSONS INJURED:
# 0.0
# 1.0
# 3.0
# 2.0
# 4.0
# 7.0
# 5.0
# 6.0
# 8.0
# 9.0
# nan
# 11.0
# 27.0
# 13.0
# 10.0
# 12.0
# 17.0
# 14.0
# 15.0
# 16.0
# 20.0
# 22.0
# 31.0
# 19.0
# 18.0
# 24.0
#
# Unikalne wartości dla kolumny NUMBER OF PEDESTRIANS INJURED:
# 0
# 1
# 2
# 3
# 4
# 5
# 27
# 6
# 7
# 9
# 13
# 15
# 8
#
# Unikalne wartości dla kolumny NUMBER OF CYCLIST INJURED:
# 0
# 1
# 2
# 3
# 4
#
# Unikalne wartości dla kolumny NUMBER OF MOTORIST INJURED:
# 0
# 1
# 3
# 2
# 4
# 7
# 5
# 6
# 8
# 9
# 11
# 13
# 10
# 12
# 17
# 14
# 15
# 16
# 20
# 21
# 31
# 19
# 18
# 24
#
# Unikalne wartości dla kolumny NUMBER OF PERSONS KILLED:
# 0.0
# 1.0
# 2.0
# nan
# 8.0
# 4.0
# 5.0
# 3.0
#
# Unikalne wartości dla kolumny NUMBER OF PEDESTRIANS KILLED:
# 0
# 1
# 2
# 6
#
# Unikalne wartości dla kolumny NUMBER OF CYCLIST KILLED:
# 0
# 1
# 2
#
# Unikalne wartości dla kolumny NUMBER OF MOTORIST KILLED:
# 0
# 1
# 2
# 5
# 3
# 4
#
# ...

# %%
def get_data_types(column):
    types = column.apply(type)
    type_counts = types.value_counts()
    nan_count = column.isna().sum()  
    type_info = '| '.join(f"{t}: {count}" for t, count in type_counts.items())
    type_info += f" | NaN: {nan_count}"  
    return type_info

columns_to_check = ['ACCIDENT DATE', 'ACCIDENT TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE', 'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME', 'OFF STREET NAME', 'NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1', 'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3', 'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5', 'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5']

mixed_type_columns = {}
for column in columns_to_check:
    if has_mixed_data_types(df[column]):
        mixed_type_columns[column] = get_data_types(df[column])

print("Kolumny z mieszanymi typami danych:")
for column, types in mixed_type_columns.items():
    print(column + ':', types)
# Out:
# Kolumny z mieszanymi typami danych:
# BOROUGH: <class 'str'>: 1127553| <class 'float'>: 484625 | NaN: 484625
# ZIP CODE: <class 'float'>: 1167616| <class 'str'>: 444562 | NaN: 484802
# LOCATION: <class 'str'>: 1415893| <class 'float'>: 196285 | NaN: 196285
# ON STREET NAME: <class 'str'>: 1298002| <class 'float'>: 314176 | NaN: 314176
# CROSS STREET NAME: <class 'str'>: 1079193| <class 'float'>: 532985 | NaN: 532985
# OFF STREET NAME: <class 'float'>: 1392446| <class 'str'>: 219732 | NaN: 1392446
# CONTRIBUTING FACTOR VEHICLE 1: <class 'str'>: 1607854| <class 'float'>: 4324 | NaN: 4324
# CONTRIBUTING FACTOR VEHICLE 2: <class 'str'>: 1396127| <class 'float'>: 216051 | NaN: 216051
# CONTRIBUTING FACTOR VEHICLE 3: <class 'float'>: 1507924| <class 'str'>: 104254 | NaN: 1507924
# CONTRIBUTING FACTOR VEHICLE 4: <class 'float'>: 1590389| <class 'str'>: 21789 | NaN: 1590389
# CONTRIBUTING FACTOR VEHICLE 5: <class 'float'>: 1606556| <class 'str'>: 5622 | NaN: 1606556
# ...

# %%
# liczba pustych kolumn ID
count_empty = df['COLLISION_ID'].isnull().sum()
print("Liczba pustych wierszy w kolumnie 'COLLISION_ID':", count_empty)
# Out:
# Liczba pustych wierszy w kolumnie 'COLLISION_ID': 0

# %%
# unikalne wartości
unique_values = df['COLLISION_ID'].nunique()
print("Liczba unikalnych wartości w kolumnie 'COLLISION_ID':", unique_values)
# Out:
# Liczba unikalnych wartości w kolumnie 'COLLISION_ID': 1217957

# %%
# liczba wierszy
total_rows = df['COLLISION_ID'].shape[0]
print("Łączna liczba wierszy w kolumnie 'COLLISION_ID':", total_rows)
# Out:
# Łączna liczba wierszy w kolumnie 'COLLISION_ID': 1612178

# %%
# WNIOSKI: 
#     1. Zbiór danych jest bardzo obszerny
#     2. Zbiór danych zawiera dużą liczbę powtórzeń 
#     3. Zbiór danych zawiera wartości nan. Wartość NaN jest przechowywana jako typ float co skutkuje warningami o pomieszanych dataTYpes
#     4. Zbiór zawiera puste wartości
# Przed analizą własciwą potrzebna jest dodatkowa interpretacja zbioru danych
